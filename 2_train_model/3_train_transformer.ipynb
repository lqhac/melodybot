# %%
import os
import pickle
import random
import subprocess
import torch.cuda
import torch
import numpy as np
from torch.utils.tensorboard import SummaryWriter
from utils.earlystopping.protocols import EarlyStopping
from test_dataloder import *
import datetime
from utils.get_time import get_time
import gc
from tqdm import tqdm
from utils.warmup import *
import torch.nn.functional as F
from transformermodel import *
from transformers import get_linear_schedule_with_warmup

# %%
src_keys = ['strength', 'length', 'phrase']
tgt_keys = ['bar', 'pos', 'token', 'dur', 'phrase']

binary_dir = '/home/qihao/CS6207/binary'
words_dir = '/home/qihao/CS6207/binary/words'
hparams = {
    'batch_size': 2,
    'word_data_dir': '/home/qihao/CS6207/binary/words',
    'sentence_maxlen': 512,
    'hidden_size': 256,
    'n_layers': 6,
    'n_head': 8,
    'pretrain': '',
    'lr': 5.0e-5,
    'optimizer_adam_beta1': 0.9,
    'optimizer_adam_beta2': 0.98,
    'weight_decay': 0.001,
    'patience': 5,
    'warmup': 2500,
    'lr': 5.0e-5,
    'checkpoint_dir': '/home/qihao/CS6207/checkpoints',
    'drop_prob': 0.2,
    'total_epoch': 1000,
    'infer_batch_size': 1,
    'temperature': 1.3,
    'topk': 5,
    'prompt_step': 1,
    'infer_max_step': 1024,
    'output_dir': "/home/qihao/CS6207/output_melody",
    'num_heads': 4,
    'enc_layers': 4, 
    'dec_layers': 4, 
    'enc_ffn_kernel_size': 1,
    'dec_ffn_kernel_size': 1,
}

# %%
def set_seed(seed=1234):  # seed setting
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    # cuDNN在使用deterministic模式时（下面两行），可能会造成性能下降（取决于model）
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
def xe_loss(outputs, targets):
    outputs = outputs.transpose(1, 2)
    return F.cross_entropy(outputs, targets, ignore_index=0, reduction='mean')

# %%
def train(train_loader, model, optimizer, scheduler, epoch, total_epoch):
    # define the format of tqdm
    with tqdm(total=len(train_loader), ncols=150, position=0, leave=True) as _tqdm:  # 总长度是data的长度
        _tqdm.set_description('training epoch: {}/{}'.format(epoch + 1, total_epoch))  # 设置前缀更新信息

        # Model Train
        model.train()
        running_loss = 0.0
        train_loss = []
        train_bar_loss = []
        train_pos_loss = []
        train_token_loss = []
        train_dur_loss = []
        train_phrase_loss = []

        for idx, data in enumerate(train_loader):
            # prompt_index = list(data[f'tgt_word'].numpy()).index(50268)
            enc_inputs = {k: data[f'src_{k}'].to(device) for k in src_keys}
            dec_inputs = {k: data[f'tgt_{k}'].to(device) for k in tgt_keys}
            
            # zero the parameter gradients
            optimizer.zero_grad()
            
            bar_out, pos_out, token_out, dur_out, phrase_out = model(enc_inputs, dec_inputs)
            
            # print(bar_out, bar_out.logit())
            
            bar_out = bar_out #.logit()
            tgt_bar = (data['tgt_bar'].to(device))[:, 1:]
            bar_loss = xe_loss(bar_out[:, :-1], tgt_bar)
            
            pos_out = pos_out #.logit()
            tgt_pos = (data['tgt_pos'].to(device))[:, 1:]
            pos_loss = xe_loss(pos_out[:, :-1], tgt_pos)
            
            token_out = token_out #.logit()
            tgt_token = (data['tgt_token'].to(device))[:, 1:]
            token_loss = xe_loss(token_out[:, :-1], tgt_token)
            
            dur_out = dur_out #.logit()
            tgt_dur = (data['tgt_dur'].to(device))[:, 1:]
            dur_loss = xe_loss(dur_out[:, :-1], tgt_dur)
            
            phrase_out = phrase_out #.logit()
            tgt_phrase = (data['tgt_phrase'].to(device))[:, 1:]
            phrase_loss = xe_loss(phrase_out[:, :-1], tgt_phrase)
            

            # 3) total loss
            total_loss = bar_loss + pos_loss + token_loss + dur_loss + phrase_loss
            total_loss.backward()
            optimizer.step()
            scheduler.step()
            train_loss.append(total_loss.item())
            running_loss += total_loss.item()
            
            train_bar_loss.append(bar_loss.item())
            train_pos_loss.append(pos_loss.item())
            train_token_loss.append(token_loss.item())
            train_dur_loss.append(dur_loss.item())
            train_phrase_loss.append(phrase_loss.item())

            _tqdm.set_postfix(
                loss="{:.3f}, bar={:.3f}, pos={:.3f}, token={:.3f}, dur={:.3f}, phrase={:.3f}".format(total_loss,
                                                                                                      bar_loss, 
                                                                                                      pos_loss,
                                                                                                      token_loss,
                                                                                                      dur_loss,
                                                                                                      phrase_loss))
            
            _tqdm.update(2)

    train_loss_avg = np.mean(train_loss)
    train_bar_loss_avg = np.mean(train_bar_loss)
    train_pos_loss_avg = np.mean(train_pos_loss)
    train_token_loss_avg = np.mean(train_token_loss)
    train_dur_loss_avg = np.mean(train_dur_loss)
    train_phrase_loss_avg = np.mean(train_phrase_loss)
    
    return train_loss_avg, train_bar_loss_avg, train_pos_loss_avg, train_token_loss_avg, train_dur_loss_avg, train_phrase_loss_avg

# %%
def valid(valid_loader, model, epoch, total_epoch):
    # define the format of tqdm
    with tqdm(total=len(valid_loader), ncols=150) as _tqdm:  # 总长度是data的长度
        _tqdm.set_description('validation epoch: {}/{}'.format(epoch + 1, total_epoch))  # 设置前缀更新信息

        model.eval()  # switch to valid mode
        running_loss = 0.0
        val_loss = []
        val_bar_loss = []
        val_pos_loss = []
        val_token_loss = []
        val_dur_loss = []
        val_phrase_loss = []

        with torch.no_grad():
            for idx, data in enumerate((valid_loader)):
                try:
                    enc_inputs = {k: data[f'src_{k}'].to(device) for k in src_keys}
                    dec_inputs = {k: data[f'tgt_{k}'].to(device) for k in tgt_keys}

                    bar_out, pos_out, token_out, dur_out, phrase_out = model(enc_inputs, dec_inputs)

                    bar_out = bar_out #.logit()
                    tgt_bar = (data['tgt_bar'].to(device))[:, 1:]
                    bar_loss = xe_loss(bar_out[:, :-1], tgt_bar)

                    pos_out = pos_out #.logit()
                    tgt_pos = (data['tgt_pos'].to(device))[:, 1:]
                    pos_loss = xe_loss(pos_out[:, :-1], tgt_pos)

                    token_out = token_out #.logit()
                    tgt_token = (data['tgt_token'].to(device))[:, 1:]
                    token_loss = xe_loss(token_out[:, :-1], tgt_token)

                    dur_out = dur_out #.logit()
                    tgt_dur = (data['tgt_dur'].to(device))[:, 1:]
                    dur_loss = xe_loss(dur_out[:, :-1], tgt_dur)

                    phrase_out = phrase_out# .logit()
                    tgt_phrase = (data['tgt_phrase'].to(device))[:, 1:]
                    phrase_loss = xe_loss(phrase_out[:, :-1], tgt_phrase)


                    # 3) total loss
                    total_loss = bar_loss + pos_loss + token_loss + dur_loss + phrase_loss
                    val_loss.append(total_loss.item())
                    running_loss += total_loss.item()

                    val_bar_loss.append(bar_loss.item())
                    val_pos_loss.append(pos_loss.item())
                    val_token_loss.append(token_loss.item())
                    val_dur_loss.append(dur_loss.item())
                    val_phrase_loss.append(phrase_loss.item())

                    _tqdm.set_postfix(
                        loss="{:.3f}, bar={:.3f}, pos={:.3f}, token={:.3f}, dur={:.3f}, phrase={:.3f}".format(total_loss,
                                                                                                              bar_loss, 
                                                                                                              pos_loss,
                                                                                                              token_loss,
                                                                                                              dur_loss,
                                                                                                              phrase_loss))

                    _tqdm.update(2)
                    
                except Exception as e:
                    print(data)
                    print("Bad Data Item!")
                    print(e)
                    break
            
    val_loss_avg = np.mean(val_loss)
    val_bar_loss_avg = np.mean(val_bar_loss)
    val_pos_loss_avg = np.mean(val_pos_loss)
    val_token_loss_avg = np.mean(val_token_loss)
    val_dur_loss_avg = np.mean(val_dur_loss)
    val_phrase_loss_avg = np.mean(val_phrase_loss)

    return val_loss_avg, val_bar_loss_avg, val_pos_loss_avg, val_token_loss_avg, val_dur_loss_avg, val_phrase_loss_avg

# %%
def train_l2m():
    ## train melody to lyric generation
    gc.collect()
    torch.cuda.empty_cache()
    
    global device
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print(device)

    # args
    set_seed()
    # set_hparams()
    event2word_dict, word2event_dict = pickle.load(open(f"{binary_dir}/music_dict.pkl", 'rb'))

    # tensorboard logger
    cur_time = get_time()
    # tensorboard_dir = hparams['tensorboard']
    # train_log_dir = f'{tensorboard_dir}/{cur_time}/train'
    # valid_log_dir = f'{tensorboard_dir}/{cur_time}/valid'
    # train_writer = SummaryWriter(log_dir=train_log_dir)
    # valid_writer = SummaryWriter(log_dir=valid_log_dir)

    # ------------
    # train
    # ------------
    # load data
    train_dataset = L2MDataset('train', event2word_dict, hparams, shuffle=True)
    valid_dataset = L2MDataset('valid', event2word_dict, hparams, shuffle=False)

    train_loader = build_dataloader(dataset=train_dataset, shuffle=True, batch_size=hparams['batch_size'], endless=False)
    val_loader = build_dataloader(dataset=valid_dataset, shuffle=False, batch_size=hparams['batch_size'], endless=False)
    
    print(len(train_loader))
    
    # print(f"foundation model pth: {hparams['custom_model_dir']}")
    
    def tensor_check_fn(key, param, input_param, error_msgs):
        if param.shape != input_param.shape:
            return False
        return True
    
    model = MusicTransformer(event2word_dict=event2word_dict, 
                             word2event_dict=word2event_dict, 
                             hidden_size=hparams['hidden_size'], 
                             num_heads=hparams['num_heads'],
                             enc_layers=hparams['enc_layers'], 
                             dec_layers=hparams['dec_layers'], 
                             dropout=hparams['drop_prob'], 
                             enc_ffn_kernel_size=hparams['enc_ffn_kernel_size'],
                             dec_ffn_kernel_size=hparams['dec_ffn_kernel_size'],
                            ).to(device)
    
    pre_trained_path = hparams['pretrain']
    if pre_trained_path != '':
        current_model_dict = model.state_dict()
        loaded_state_dict = torch.load(pre_trained_path)
        new_state_dict={k:v if v.size()==current_model_dict[k].size() else current_model_dict[k] for k,v in zip(current_model_dict.keys(), loaded_state_dict.values())}
        # model.load_state_dict(new_state_dict, strict=False)
        # model.load_state_dict(torch.load(pre_trained_path), strict=False, tensor_check_fn=tensor_check_fn)
        model.load_state_dict(new_state_dict, strict=False)
        print(">>> Load pretrained model successfully")
        
    ## warm up
    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=hparams['lr'],
        betas=(hparams['optimizer_adam_beta1'], hparams['optimizer_adam_beta2']),
        weight_decay=hparams['weight_decay'])

    scheduler = get_linear_schedule_with_warmup(
        optimizer, num_warmup_steps=hparams['warmup'], num_training_steps=-1
    )

    """
    if torch.cuda.device_count() > 1:
        print("Using", torch.cuda.device_count(), "GPUs!")
        model = torch.nn.DataParallel(model)
    model.to(device)
    """

    # training conditions (for naming the ckpt)
    lr = hparams['lr']

    # early stop: initialize the early_stopping object
    # checkpointpath = f"{hparams['checkpoint_dir']}/Cond_{cond}_GPT2_{cur_time}_lr{lr}"
    checkpointpath = f"{hparams['checkpoint_dir']}/checkpoint_{cur_time}_lr_{lr}"
    if not os.path.exists(checkpointpath):
        os.mkdir(checkpointpath)
    early_stopping = EarlyStopping(patience=hparams['patience'], verbose=True,
                                   path=f"{checkpointpath}/early_stopping_checkpoint.pt")
    

    # -------- Train & Validation -------- #
    min_valid_running_loss = 1000000  # inf
    total_epoch = hparams['total_epoch']
    with tqdm(total=total_epoch) as _tqdm:
        for epoch in range(total_epoch):
            # Train
            train_running_loss, _, _, _, _, _ = train(train_loader, model, optimizer, scheduler, epoch, total_epoch)
            # train_writer.add_scalars("train_epoch_loss", {"running": train_running_loss, 'word': train_word_loss}, epoch)

            # validation  
            valid_running_loss, _, _, _, _, _ = valid(val_loader, model, epoch, total_epoch)
            # valid_writer.add_scalars("valid_epoch_loss", {"running": valid_running_loss, 'word': valid_word_loss}, epoch)

            # early stopping Check
            early_stopping(valid_running_loss, model, epoch)
            if early_stopping.early_stop == True:
                print("Validation Loss convergence， Train over")
                break

            # save the best checkpoint
            if valid_running_loss < min_valid_running_loss:
                min_valid_running_loss = valid_running_loss
                torch.save(model.state_dict(), f"{checkpointpath}/best.pt")
            print(f"Training Runinng Loss = {train_running_loss}, Validation Running Loss = {min_valid_running_loss}")  
            _tqdm.update(2)

# %%
train_l2m()
# Out:
# cuda:0
# 1545
# training epoch: 1/1000:   0%|                                                                                                | 0/1545 [00:00<?, ?it/s]/home/qihao/anaconda3/envs/xailyr/lib/python3.9/site-packages/torch/nn/functional.py:4999: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# training epoch: 1/1000: : 3090it [00:47, 64.75it/s, loss=9.764, bar=2.347, pos=2.423, token=2.853, dur=1.799, phrase=0.342]
#
#   0%|                                                                                                                         | 0/193 [00:00<?, ?it/s]
# validation epoch: 1/1000:   0%|                                                                                               | 0/193 [00:00<?, ?it/s]
# validation epoch: 1/1000:   0%|                      | 0/193 [00:00<?, ?it/s, loss=11.550, bar=3.663, pos=2.646, token=3.368, dur=1.538, phrase=0.335]
# validation epoch: 1/1000:   1%|▏             | 2/193 [00:00<00:38,  5.00it/s, loss=11.550, bar=3.663, pos=2.646, token=3.368, dur=1.538, phrase=0.335]
# validation epoch: 1/1000:   1%|▏              | 2/193 [00:00<00:38,  5.00it/s, loss=8.803, bar=2.452, pos=1.870, token=2.690, dur=1.375, phrase=0.416]
# validation epoch: 1/1000:   2%|▎              | 4/193 [00:00<00:37,  5.00it/s, loss=9.878, bar=2.155, pos=2.343, token=3.032, dur=1.770, phrase=0.579]
# validation epoch: 1/1000:   3%|▍             | 6/193 [00:00<00:37,  5.00it/s, loss=11.360, bar=3.213, pos=2.577, token=2.791, dur=2.275, phrase=0.504]
# validation epoch: 1/1000:   4%|▌             | 8/193 [00:00<00:37,  5.00it/s, loss=11.619, bar=4.235, pos=2.536, token=2.609, dur=1.776, phrase=0.463]
# validation epoch: 1/1000:   5%|▋             | 10/193 [00:00<00:36,  5.00it/s, loss=9.854, bar=2.837, pos=2.396, token=2.796, dur=1.436, phrase=0.390]
# validation epoch: 1/1000:   6%|▊            | 12/193 [00:00<00:36,  5.00it/s, loss=11.039, bar=2.408, pos=2.208, token=3.866, dur=2.058, phrase=0.498]
# validation epoch: 1/1000:   7%|▉            | 14/193 [00:00<00:35,  5.00it/s, loss=10.927, bar=3.002, pos=2.528, token=3.168, dur=1.872, phrase=0.357]
# validation epoch: 1/1000:   8%|█            | 16/193 [00:00<00:35,  5.00it/s, loss=13.408, bar=4.927, pos=2.054, token=3.674, dur=2.013, phrase=0.740]
# validation epoch: 1/1000:   9%|█▏           | 18/193 [00:00<00:03, 45.06it/s, loss=13.408, bar=4.927, pos=2.054, token=3.674, dur=2.013, phrase=0.740]
# validation epoch: 1/1000:   9%|█▏           | 18/193 [00:00<00:03, 45.06it/s, loss=10.551, bar=2.540, pos=2.118, token=3.877, dur=1.545, phrase=0.471]
# validation epoch: 1/1000:  10%|█▍            | 20/193 [00:00<00:03, 45.06it/s, loss=8.126, bar=2.108, pos=1.625, token=2.649, dur=1.213, phrase=0.532]
# validation epoch: 1/1000:  11%|█▌            | 22/193 [00:00<00:03, 45.06it/s, loss=8.314, bar=2.112, pos=2.036, token=2.474, dur=1.288, phrase=0.404]
# validation epoch: 1/1000:  12%|█▋            | 24/193 [00:00<00:03, 45.06it/s, loss=8.364, bar=2.106, pos=1.964, token=2.484, dur=1.470, phrase=0.340]
# validation epoch: 1/1000:  13%|█▊           | 26/193 [00:00<00:03, 45.06it/s, loss=10.342, bar=3.170, pos=2.437, token=2.822, dur=1.547, phrase=0.366]
# validation epoch: 1/1000:  15%|█▉           | 28/193 [00:00<00:03, 45.06it/s, loss=10.743, bar=2.707, pos=2.495, token=3.543, dur=1.679, phrase=0.320]
# validation epoch: 1/1000:  16%|██           | 30/193 [00:00<00:03, 45.06it/s, loss=10.518, bar=3.139, pos=2.715, token=2.980, dur=1.406, phrase=0.278]
# validation epoch: 1/1000:  17%|██▏          | 32/193 [00:00<00:03, 45.06it/s, loss=10.011, bar=2.258, pos=2.480, token=2.962, dur=1.923, phrase=0.389]
# validation epoch: 1/1000:  18%|██▍           | 34/193 [00:00<00:03, 45.06it/s, loss=8.821, bar=2.271, pos=1.801, token=2.534, dur=1.666, phrase=0.550]
# validation epoch: 1/1000:  19%|██▌           | 36/193 [00:00<00:03, 45.06it/s, loss=9.536, bar=2.299, pos=2.151, token=3.051, dur=1.651, phrase=0.384]
# validation epoch: 1/1000:  20%|██▊           | 38/193 [00:00<00:01, 85.53it/s, loss=9.536, bar=2.299, pos=2.151, token=3.051, dur=1.651, phrase=0.384]
# validation epoch: 1/1000:  20%|██▊           | 38/193 [00:00<00:01, 85.53it/s, loss=8.990, bar=2.774, pos=1.603, token=2.806, dur=1.326, phrase=0.481]
# validation epoch: 1/1000:  21%|██▉           | 40/193 [00:00<00:01, 85.53it/s, loss=9.065, bar=2.404, pos=2.041, token=2.779, dur=1.433, phrase=0.407]
# validation epoch: 1/1000:  22%|██▊          | 42/193 [00:00<00:01, 85.53it/s, loss=10.816, bar=2.979, pos=2.827, token=3.041, dur=1.653, phrase=0.317]
# validation epoch: 1/1000:  23%|██▉          | 44/193 [00:00<00:01, 85.53it/s, loss=10.397, bar=3.898, pos=2.118, token=2.486, dur=1.424, phrase=0.471]
# validation epoch: 1/1000:  24%|███▎          | 46/193 [00:00<00:01, 85.53it/s, loss=9.431, bar=2.324, pos=2.138, token=2.721, dur=1.901, phrase=0.347]
# validation epoch: 1/1000:  25%|███▍          | 48/193 [00:00<00:01, 85.53it/s, loss=9.208, bar=2.373, pos=1.933, token=2.651, dur=1.704, phrase=0.548]
# validation epoch: 1/1000:  26%|███▎         | 50/193 [00:00<00:01, 85.53it/s, loss=10.753, bar=2.528, pos=2.655, token=2.701, dur=2.444, phrase=0.425]
# validation epoch: 1/1000:  27%|███▌         | 52/193 [00:00<00:01, 85.53it/s, loss=10.889, bar=2.817, pos=2.617, token=3.366, dur=1.742, phrase=0.348]
# validation epoch: 1/1000:  28%|███▋         | 54/193 [00:00<00:01, 85.53it/s, loss=11.032, bar=3.313, pos=2.115, token=3.772, dur=1.479, phrase=0.353]
# validation epoch: 1/1000:  29%|███▍        | 56/193 [00:00<00:01, 109.56it/s, loss=11.032, bar=3.313, pos=2.115, token=3.772, dur=1.479, phrase=0.353]
# validation epoch: 1/1000:  29%|███▍        | 56/193 [00:00<00:01, 109.56it/s, loss=11.790, bar=4.294, pos=2.328, token=2.579, dur=2.096, phrase=0.493]
# validation epoch: 1/1000:  30%|███▌        | 58/193 [00:00<00:01, 109.56it/s, loss=10.388, bar=3.301, pos=2.118, token=2.671, dur=1.754, phrase=0.544]
# validation epoch: 1/1000:  31%|███▋        | 60/193 [00:00<00:01, 109.56it/s, loss=11.071, bar=2.866, pos=2.487, token=3.736, dur=1.653, phrase=0.330]
# validation epoch: 1/1000:  32%|███▊        | 62/193 [00:00<00:01, 109.56it/s, loss=10.180, bar=2.889, pos=2.302, token=3.090, dur=1.483, phrase=0.417]
# validation epoch: 1/1000:  33%|████▎        | 64/193 [00:00<00:01, 109.56it/s, loss=8.639, bar=2.670, pos=2.121, token=2.471, dur=1.076, phrase=0.300]
# validation epoch: 1/1000:  34%|████▍        | 66/193 [00:00<00:01, 109.56it/s, loss=9.942, bar=2.524, pos=2.190, token=3.510, dur=1.340, phrase=0.377]
# validation epoch: 1/1000:  35%|████▏       | 68/193 [00:00<00:01, 109.56it/s, loss=10.690, bar=3.326, pos=2.359, token=2.999, dur=1.630, phrase=0.377]
# validation epoch: 1/1000:  36%|████▎       | 70/193 [00:00<00:01, 109.56it/s, loss=10.332, bar=2.467, pos=2.284, token=3.289, dur=1.792, phrase=0.501]
# validation epoch: 1/1000:  37%|████▍       | 72/193 [00:00<00:01, 109.56it/s, loss=11.213, bar=3.387, pos=2.267, token=3.700, dur=1.452, phrase=0.406]
# validation epoch: 1/1000:  38%|████▌       | 74/193 [00:00<00:00, 126.97it/s, loss=11.213, bar=3.387, pos=2.267, token=3.700, dur=1.452, phrase=0.406]
# validation epoch: 1/1000:  38%|████▌       | 74/193 [00:00<00:00, 126.97it/s, loss=10.871, bar=2.975, pos=2.545, token=3.130, dur=1.798, phrase=0.422]
# validation epoch: 1/1000:  39%|█████        | 76/193 [00:00<00:00, 126.97it/s, loss=9.187, bar=2.447, pos=2.003, token=2.529, dur=1.873, phrase=0.334]
# validation epoch: 1/1000:  40%|█████▎       | 78/193 [00:00<00:00, 126.97it/s, loss=9.752, bar=2.267, pos=2.100, token=3.020, dur=1.897, phrase=0.468]
# validation epoch: 1/1000:  41%|█████▍       | 80/193 [00:00<00:00, 126.97it/s, loss=8.741, bar=2.447, pos=1.651, token=2.755, dur=1.406, phrase=0.482]
# validation epoch: 1/1000:  42%|█████       | 82/193 [00:00<00:00, 126.97it/s, loss=10.276, bar=3.583, pos=2.288, token=2.619, dur=1.461, phrase=0.325]
# validation epoch: 1/1000:  44%|█████▋       | 84/193 [00:00<00:00, 126.97it/s, loss=8.962, bar=2.566, pos=1.812, token=2.778, dur=1.332, phrase=0.474]
# validation epoch: 1/1000:  45%|█████▊       | 86/193 [00:00<00:00, 126.97it/s, loss=9.365, bar=3.156, pos=2.023, token=2.674, dur=1.220, phrase=0.292]
# validation epoch: 1/1000:  46%|█████▍      | 88/193 [00:00<00:00, 126.97it/s, loss=10.987, bar=3.027, pos=2.335, token=3.107, dur=1.990, phrase=0.528]
# validation epoch: 1/1000:  47%|█████▌      | 90/193 [00:00<00:00, 130.56it/s, loss=10.987, bar=3.027, pos=2.335, token=3.107, dur=1.990, phrase=0.528]
# validation epoch: 1/1000:  47%|██████       | 90/193 [00:00<00:00, 130.56it/s, loss=9.154, bar=2.318, pos=1.963, token=2.815, dur=1.610, phrase=0.449]
# validation epoch: 1/1000:  48%|█████▋      | 92/193 [00:00<00:00, 130.56it/s, loss=12.252, bar=3.523, pos=2.361, token=3.286, dur=2.579, phrase=0.503]
# validation epoch: 1/1000:  49%|██████▎      | 94/193 [00:00<00:00, 130.56it/s, loss=9.662, bar=2.731, pos=2.081, token=2.701, dur=1.606, phrase=0.543]
# validation epoch: 1/1000:  50%|█████▉      | 96/193 [00:00<00:00, 130.56it/s, loss=10.077, bar=2.388, pos=2.060, token=3.845, dur=1.412, phrase=0.372]
# validation epoch: 1/1000:  51%|██████▌      | 98/193 [00:01<00:00, 130.56it/s, loss=8.678, bar=2.150, pos=1.874, token=3.002, dur=1.250, phrase=0.401]
# validation epoch: 1/1000:  52%|██████▏     | 100/193 [00:01<00:00, 130.56it/s, loss=8.904, bar=2.521, pos=1.957, token=2.524, dur=1.454, phrase=0.448]
# validation epoch: 1/1000:  53%|█████▊     | 102/193 [00:01<00:00, 130.56it/s, loss=10.244, bar=3.231, pos=2.401, token=2.670, dur=1.560, phrase=0.383]
# validation epoch: 1/1000:  54%|█████▉     | 104/193 [00:01<00:00, 130.56it/s, loss=11.591, bar=2.517, pos=2.084, token=4.987, dur=1.548, phrase=0.454]
# validation epoch: 1/1000:  55%|██████     | 106/193 [00:01<00:00, 130.56it/s, loss=10.802, bar=3.537, pos=1.978, token=3.360, dur=1.440, phrase=0.487]
# validation epoch: 1/1000:  56%|██████▏    | 108/193 [00:01<00:00, 140.99it/s, loss=10.802, bar=3.537, pos=1.978, token=3.360, dur=1.440, phrase=0.487]
# validation epoch: 1/1000:  56%|██████▋     | 108/193 [00:01<00:00, 140.99it/s, loss=9.347, bar=2.444, pos=1.987, token=3.056, dur=1.479, phrase=0.380]
# validation epoch: 1/1000:  57%|██████▊     | 110/193 [00:01<00:00, 140.99it/s, loss=9.951, bar=2.324, pos=2.106, token=3.251, dur=1.773, phrase=0.497]
# validation epoch: 1/1000:  58%|██████▍    | 112/193 [00:01<00:00, 140.99it/s, loss=10.982, bar=3.425, pos=2.227, token=3.189, dur=1.649, phrase=0.492]
# validation epoch: 1/1000:  59%|██████▍    | 114/193 [00:01<00:00, 140.99it/s, loss=10.554, bar=2.990, pos=2.426, token=3.355, dur=1.439, phrase=0.344]
# validation epoch: 1/1000:  60%|███████▏    | 116/193 [00:01<00:00, 140.99it/s, loss=9.665, bar=2.945, pos=2.042, token=2.834, dur=1.404, phrase=0.440]
# validation epoch: 1/1000:  61%|███████▎    | 118/193 [00:01<00:00, 140.99it/s, loss=8.437, bar=2.318, pos=1.935, token=2.452, dur=1.260, phrase=0.472]
# validation epoch: 1/1000:  62%|██████▊    | 120/193 [00:01<00:00, 140.99it/s, loss=11.067, bar=2.332, pos=2.613, token=3.484, dur=2.220, phrase=0.417]
# validation epoch: 1/1000:  63%|██████▉    | 122/193 [00:01<00:00, 140.99it/s, loss=10.319, bar=2.828, pos=2.670, token=2.833, dur=1.605, phrase=0.383]
# validation epoch: 1/1000:  64%|███████    | 124/193 [00:01<00:00, 140.99it/s, loss=10.566, bar=2.199, pos=2.358, token=3.164, dur=2.306, phrase=0.539]
# validation epoch: 1/1000:  65%|███████▏   | 126/193 [00:01<00:00, 148.61it/s, loss=10.566, bar=2.199, pos=2.358, token=3.164, dur=2.306, phrase=0.539]
# validation epoch: 1/1000:  65%|███████▏   | 126/193 [00:01<00:00, 148.61it/s, loss=11.007, bar=4.364, pos=2.002, token=2.644, dur=1.559, phrase=0.439]
# validation epoch: 1/1000:  66%|███████▉    | 128/193 [00:01<00:00, 148.61it/s, loss=9.357, bar=2.369, pos=2.251, token=2.521, dur=1.676, phrase=0.540]
# validation epoch: 1/1000:  67%|███████▍   | 130/193 [00:01<00:00, 148.61it/s, loss=12.124, bar=3.878, pos=2.239, token=3.264, dur=2.214, phrase=0.530]
# validation epoch: 1/1000:  68%|███████▌   | 132/193 [00:01<00:00, 148.61it/s, loss=11.017, bar=3.668, pos=2.320, token=2.732, dur=1.868, phrase=0.429]
# validation epoch: 1/1000:  69%|███████▋   | 134/193 [00:01<00:00, 148.61it/s, loss=10.541, bar=3.158, pos=2.571, token=2.646, dur=1.787, phrase=0.379]
# validation epoch: 1/1000:  70%|███████▊   | 136/193 [00:01<00:00, 148.61it/s, loss=12.721, bar=3.275, pos=2.932, token=3.001, dur=3.055, phrase=0.457]
# validation epoch: 1/1000:  72%|███████▊   | 138/193 [00:01<00:00, 148.61it/s, loss=10.993, bar=3.617, pos=2.464, token=2.908, dur=1.610, phrase=0.395]
# validation epoch: 1/1000:  73%|███████▉   | 140/193 [00:01<00:00, 148.61it/s, loss=11.340, bar=3.502, pos=2.118, token=3.129, dur=2.048, phrase=0.543]
# validation epoch: 1/1000:  74%|████████▊   | 142/193 [00:01<00:00, 148.61it/s, loss=8.989, bar=2.411, pos=1.986, token=2.805, dur=1.331, phrase=0.456]
# validation epoch: 1/1000:  75%|████████▉   | 144/193 [00:01<00:00, 154.49it/s, loss=8.989, bar=2.411, pos=1.986, token=2.805, dur=1.331, phrase=0.456]
# validation epoch: 1/1000:  75%|████████▉   | 144/193 [00:01<00:00, 154.49it/s, loss=8.487, bar=2.488, pos=1.974, token=2.447, dur=1.235, phrase=0.342]
# validation epoch: 1/1000:  76%|████████▎  | 146/193 [00:01<00:00, 154.49it/s, loss=10.579, bar=3.294, pos=2.659, token=2.819, dur=1.479, phrase=0.328]
# validation epoch: 1/1000:  77%|████████▍  | 148/193 [00:01<00:00, 154.49it/s, loss=10.261, bar=2.803, pos=2.293, token=3.154, dur=1.570, phrase=0.442]
# validation epoch: 1/1000:  78%|████████▌  | 150/193 [00:01<00:00, 154.49it/s, loss=10.741, bar=2.528, pos=2.191, token=2.859, dur=2.502, phrase=0.661]
# validation epoch: 1/1000:  79%|████████▋  | 152/193 [00:01<00:00, 154.49it/s, loss=10.882, bar=2.175, pos=2.428, token=3.660, dur=2.205, phrase=0.414]
# validation epoch: 1/1000:  80%|█████████▌  | 154/193 [00:01<00:00, 154.49it/s, loss=8.938, bar=2.763, pos=1.985, token=2.489, dur=1.290, phrase=0.411]
# validation epoch: 1/1000:  81%|████████▉  | 156/193 [00:01<00:00, 154.49it/s, loss=10.275, bar=3.047, pos=2.355, token=2.729, dur=1.840, phrase=0.305]
# validation epoch: 1/1000:  82%|█████████▊  | 158/193 [00:01<00:00, 154.49it/s, loss=9.087, bar=2.453, pos=2.233, token=2.768, dur=1.281, phrase=0.353]
# validation epoch: 1/1000:  83%|█████████  | 160/193 [00:01<00:00, 154.49it/s, loss=10.538, bar=2.393, pos=2.375, token=3.525, dur=1.743, phrase=0.501]
# validation epoch: 1/1000:  84%|█████████▏ | 162/193 [00:01<00:00, 158.11it/s, loss=10.538, bar=2.393, pos=2.375, token=3.525, dur=1.743, phrase=0.501]
# validation epoch: 1/1000:  84%|██████████  | 162/193 [00:01<00:00, 158.11it/s, loss=9.825, bar=2.389, pos=2.330, token=2.701, dur=2.023, phrase=0.381]
# validation epoch: 1/1000:  85%|██████████▏ | 164/193 [00:01<00:00, 158.11it/s, loss=8.966, bar=2.283, pos=1.988, token=2.587, dur=1.773, phrase=0.335]
# validation epoch: 1/1000:  86%|█████████▍ | 166/193 [00:01<00:00, 158.11it/s, loss=10.462, bar=2.798, pos=2.863, token=2.573, dur=1.840, phrase=0.389]
# validation epoch: 1/1000:  87%|█████████▌ | 168/193 [00:01<00:00, 158.11it/s, loss=10.708, bar=3.482, pos=2.547, token=2.673, dur=1.649, phrase=0.358]
# validation epoch: 1/1000:  88%|██████████▌ | 170/193 [00:01<00:00, 158.11it/s, loss=9.770, bar=2.601, pos=1.903, token=3.087, dur=1.758, phrase=0.421]
# validation epoch: 1/1000:  89%|██████████▋ | 172/193 [00:01<00:00, 158.11it/s, loss=9.822, bar=2.458, pos=2.385, token=2.565, dur=1.964, phrase=0.451]
# validation epoch: 1/1000:  90%|██████████▊ | 174/193 [00:01<00:00, 158.11it/s, loss=9.369, bar=2.761, pos=2.068, token=2.879, dur=1.234, phrase=0.427]
# validation epoch: 1/1000:  91%|██████████ | 176/193 [00:01<00:00, 158.11it/s, loss=12.770, bar=4.929, pos=2.462, token=3.362, dur=1.586, phrase=0.431]
# validation epoch: 1/1000:  92%|██████████▏| 178/193 [00:01<00:00, 158.11it/s, loss=11.125, bar=3.712, pos=2.050, token=3.479, dur=1.462, phrase=0.423]
# validation epoch: 1/1000:  93%|██████████▎| 180/193 [00:01<00:00, 158.30it/s, loss=11.125, bar=3.712, pos=2.050, token=3.479, dur=1.462, phrase=0.423]
# validation epoch: 1/1000:  93%|██████████▎| 180/193 [00:01<00:00, 158.30it/s, loss=10.115, bar=2.720, pos=2.147, token=2.963, dur=1.825, phrase=0.459]
# validation epoch: 1/1000:  94%|███████████▎| 182/193 [00:01<00:00, 158.30it/s, loss=9.752, bar=2.659, pos=1.909, token=3.238, dur=1.451, phrase=0.495]
# validation epoch: 1/1000:  95%|███████████▍| 184/193 [00:01<00:00, 158.30it/s, loss=9.894, bar=2.863, pos=2.456, token=2.631, dur=1.607, phrase=0.336]
# validation epoch: 1/1000:  96%|██████████▌| 186/193 [00:01<00:00, 158.30it/s, loss=10.457, bar=3.127, pos=2.493, token=2.962, dur=1.528, phrase=0.347]
# validation epoch: 1/1000:  97%|██████████▋| 188/193 [00:01<00:00, 158.30it/s, loss=10.210, bar=2.520, pos=2.141, token=3.571, dur=1.489, phrase=0.489]
# validation epoch: 1/1000:  98%|██████████▊| 190/193 [00:01<00:00, 158.30it/s, loss=10.410, bar=3.018, pos=2.403, token=2.836, dur=1.795, phrase=0.358]
# validation epoch: 1/1000:  99%|██████████▉| 192/193 [00:01<00:00, 158.30it/s, loss=10.184, bar=2.825, pos=2.269, token=2.895, dur=1.793, phrase=0.402]
# validation epoch: 1/1000: : 194it [00:01, 158.30it/s, loss=10.867, bar=3.391, pos=2.243, token=2.844, dur=2.008, phrase=0.381]
# validation epoch: 1/1000: : 196it [00:01, 158.30it/s, loss=9.774, bar=3.578, pos=1.851, token=2.633, dur=1.332, phrase=0.381]
# validation epoch: 1/1000: : 198it [00:01, 160.81it/s, loss=9.774, bar=3.578, pos=1.851, token=2.633, dur=1.332, phrase=0.381]
# validation epoch: 1/1000: : 198it [00:01, 160.81it/s, loss=10.203, bar=3.722, pos=1.774, token=2.684, dur=1.484, phrase=0.538]
# validation epoch: 1/1000: : 200it [00:01, 160.81it/s, loss=10.057, bar=2.880, pos=2.312, token=2.545, dur=1.907, phrase=0.412]
# validation epoch: 1/1000: : 202it [00:01, 160.81it/s, loss=11.116, bar=2.746, pos=2.674, token=2.864, dur=2.427, phrase=0.406]
# validation epoch: 1/1000: : 204it [00:01, 160.81it/s, loss=10.676, bar=2.871, pos=2.668, token=2.599, dur=2.058, phrase=0.482]
# validation epoch: 1/1000: : 206it [00:01, 160.81it/s, loss=10.455, bar=2.444, pos=2.258, token=3.115, dur=2.086, phrase=0.551]
# validation epoch: 1/1000: : 208it [00:01, 160.81it/s, loss=8.804, bar=2.394, pos=1.767, token=2.984, dur=1.260, phrase=0.399]
# validation epoch: 1/1000: : 210it [00:01, 160.81it/s, loss=9.821, bar=2.735, pos=2.168, token=2.965, dur=1.532, phrase=0.421]
# validation epoch: 1/1000: : 212it [00:01, 160.81it/s, loss=10.243, bar=3.367, pos=2.319, token=2.731, dur=1.471, phrase=0.356]
# validation epoch: 1/1000: : 214it [00:01, 160.81it/s, loss=9.836, bar=3.116, pos=2.208, token=2.674, dur=1.490, phrase=0.349]
# validation epoch: 1/1000: : 216it [00:01, 162.97it/s, loss=9.836, bar=3.116, pos=2.208, token=2.674, dur=1.490, phrase=0.349]
# validation epoch: 1/1000: : 216it [00:01, 162.97it/s, loss=8.982, bar=2.447, pos=1.996, token=2.500, dur=1.642, phrase=0.398]
# validation epoch: 1/1000: : 218it [00:01, 162.97it/s, loss=11.049, bar=2.782, pos=2.799, token=2.983, dur=2.172, phrase=0.312]
# validation epoch: 1/1000: : 220it [00:01, 162.97it/s, loss=9.421, bar=2.615, pos=1.806, token=2.742, dur=1.800, phrase=0.459]
# validation epoch: 1/1000: : 222it [00:01, 162.97it/s, loss=11.430, bar=3.616, pos=2.027, token=3.223, dur=1.966, phrase=0.598]
# validation epoch: 1/1000: : 224it [00:01, 162.97it/s, loss=9.842, bar=3.281, pos=2.070, token=2.696, dur=1.451, phrase=0.344]
# validation epoch: 1/1000: : 226it [00:01, 162.97it/s, loss=9.219, bar=2.369, pos=2.167, token=2.574, dur=1.690, phrase=0.420]
# validation epoch: 1/1000: : 228it [00:01, 162.97it/s, loss=9.880, bar=3.370, pos=1.912, token=2.801, dur=1.331, phrase=0.465]
# validation epoch: 1/1000: : 230it [00:01, 162.97it/s, loss=10.649, bar=3.393, pos=2.507, token=2.731, dur=1.668, phrase=0.350]
# validation epoch: 1/1000: : 232it [00:01, 162.97it/s, loss=11.542, bar=3.831, pos=2.143, token=3.119, dur=1.895, phrase=0.554]
# validation epoch: 1/1000: : 234it [00:01, 164.48it/s, loss=11.542, bar=3.831, pos=2.143, token=3.119, dur=1.895, phrase=0.554]
# validation epoch: 1/1000: : 234it [00:01, 164.48it/s, loss=11.738, bar=2.321, pos=2.577, token=3.190, dur=3.015, phrase=0.635]
# validation epoch: 1/1000: : 236it [00:01, 164.48it/s, loss=11.523, bar=3.468, pos=2.297, token=3.238, dur=1.992, phrase=0.528]
# validation epoch: 1/1000: : 238it [00:01, 164.48it/s, loss=9.764, bar=2.343, pos=2.114, token=2.879, dur=1.935, phrase=0.492]
# validation epoch: 1/1000: : 240it [00:01, 164.48it/s, loss=10.595, bar=2.575, pos=2.306, token=2.597, dur=2.499, phrase=0.619]
# validation epoch: 1/1000: : 242it [00:01, 164.48it/s, loss=10.214, bar=3.042, pos=2.655, token=2.501, dur=1.677, phrase=0.339]
# validation epoch: 1/1000: : 244it [00:01, 164.48it/s, loss=11.683, bar=2.854, pos=2.463, token=4.220, dur=1.741, phrase=0.404]
# validation epoch: 1/1000: : 246it [00:01, 164.48it/s, loss=9.909, bar=2.956, pos=2.036, token=2.753, dur=1.636, phrase=0.527]
# validation epoch: 1/1000: : 248it [00:01, 164.48it/s, loss=9.835, bar=2.315, pos=2.226, token=2.750, dur=2.027, phrase=0.518]
# validation epoch: 1/1000: : 250it [00:01, 164.48it/s, loss=11.414, bar=3.105, pos=2.586, token=3.117, dur=2.148, phrase=0.458]
# validation epoch: 1/1000: : 252it [00:01, 165.95it/s, loss=11.414, bar=3.105, pos=2.586, token=3.117, dur=2.148, phrase=0.458]
# validation epoch: 1/1000: : 252it [00:01, 165.95it/s, loss=9.939, bar=3.191, pos=2.177, token=2.671, dur=1.431, phrase=0.469]
# validation epoch: 1/1000: : 254it [00:01, 165.95it/s, loss=10.979, bar=3.248, pos=2.493, token=3.095, dur=1.804, phrase=0.340]
# validation epoch: 1/1000: : 256it [00:01, 165.95it/s, loss=10.103, bar=3.415, pos=2.042, token=2.666, dur=1.512, phrase=0.467]
# validation epoch: 1/1000: : 258it [00:01, 165.95it/s, loss=10.303, bar=2.910, pos=2.783, token=2.603, dur=1.653, phrase=0.353]
# validation epoch: 1/1000: : 260it [00:01, 165.95it/s, loss=9.902, bar=3.040, pos=2.093, token=2.646, dur=1.586, phrase=0.538]
# validation epoch: 1/1000: : 262it [00:01, 165.95it/s, loss=11.551, bar=3.366, pos=1.842, token=4.380, dur=1.466, phrase=0.498]
# validation epoch: 1/1000: : 264it [00:01, 165.95it/s, loss=10.412, bar=3.171, pos=2.675, token=2.572, dur=1.651, phrase=0.343]
# validation epoch: 1/1000: : 266it [00:02, 165.95it/s, loss=10.064, bar=3.148, pos=2.082, token=2.934, dur=1.411, phrase=0.489]
# validation epoch: 1/1000: : 268it [00:02, 165.95it/s, loss=10.581, bar=2.703, pos=2.192, token=2.842, dur=2.200, phrase=0.643]
# validation epoch: 1/1000: : 270it [00:02, 166.19it/s, loss=10.581, bar=2.703, pos=2.192, token=2.842, dur=2.200, phrase=0.643]
# validation epoch: 1/1000: : 270it [00:02, 166.19it/s, loss=11.425, bar=3.250, pos=2.787, token=2.833, dur=2.089, phrase=0.466]
# validation epoch: 1/1000: : 272it [00:02, 166.19it/s, loss=10.198, bar=2.922, pos=2.020, token=2.955, dur=1.850, phrase=0.451]
# validation epoch: 1/1000: : 274it [00:02, 166.19it/s, loss=10.613, bar=2.332, pos=2.449, token=3.206, dur=2.110, phrase=0.516]
# validation epoch: 1/1000: : 276it [00:02, 166.19it/s, loss=10.004, bar=2.892, pos=2.112, token=3.099, dur=1.478, phrase=0.423]
# validation epoch: 1/1000: : 278it [00:02, 166.19it/s, loss=9.362, bar=2.498, pos=2.070, token=2.946, dur=1.429, phrase=0.418]
# validation epoch: 1/1000: : 280it [00:02, 166.19it/s, loss=9.133, bar=2.481, pos=2.091, token=2.845, dur=1.228, phrase=0.489]
# validation epoch: 1/1000: : 282it [00:02, 166.19it/s, loss=9.081, bar=2.359, pos=1.931, token=2.723, dur=1.521, phrase=0.547]
# validation epoch: 1/1000: : 284it [00:02, 166.19it/s, loss=11.307, bar=3.726, pos=2.845, token=2.645, dur=1.800, phrase=0.291]
# validation epoch: 1/1000: : 286it [00:02, 166.19it/s, loss=10.713, bar=2.724, pos=2.308, token=3.523, dur=1.818, phrase=0.340]
# validation epoch: 1/1000: : 288it [00:02, 166.77it/s, loss=10.713, bar=2.724, pos=2.308, token=3.523, dur=1.818, phrase=0.340]
# validation epoch: 1/1000: : 288it [00:02, 166.77it/s, loss=8.748, bar=2.510, pos=1.946, token=2.722, dur=1.179, phrase=0.391]
# validation epoch: 1/1000: : 290it [00:02, 166.77it/s, loss=10.659, bar=3.949, pos=2.086, token=2.863, dur=1.386, phrase=0.375]
# validation epoch: 1/1000: : 292it [00:02, 166.77it/s, loss=11.127, bar=3.527, pos=2.273, token=2.994, dur=1.858, phrase=0.475]
# validation epoch: 1/1000: : 294it [00:02, 166.77it/s, loss=8.636, bar=2.211, pos=1.761, token=2.826, dur=1.428, phrase=0.410]
# validation epoch: 1/1000: : 296it [00:02, 166.77it/s, loss=9.843, bar=2.676, pos=1.879, token=3.247, dur=1.579, phrase=0.463]
# validation epoch: 1/1000: : 298it [00:02, 166.77it/s, loss=10.442, bar=2.924, pos=1.983, token=3.770, dur=1.322, phrase=0.444]
# validation epoch: 1/1000: : 300it [00:02, 166.77it/s, loss=12.448, bar=2.566, pos=2.336, token=5.193, dur=1.932, phrase=0.421]
# validation epoch: 1/1000: : 302it [00:02, 166.77it/s, loss=9.967, bar=1.999, pos=2.144, token=3.648, dur=1.665, phrase=0.510]
# validation epoch: 1/1000: : 304it [00:02, 166.77it/s, loss=9.217, bar=2.435, pos=1.909, token=2.816, dur=1.596, phrase=0.462]
# validation epoch: 1/1000: : 306it [00:02, 166.33it/s, loss=9.217, bar=2.435, pos=1.909, token=2.816, dur=1.596, phrase=0.462]
# validation epoch: 1/1000: : 306it [00:02, 166.33it/s, loss=9.930, bar=3.097, pos=1.926, token=2.743, dur=1.654, phrase=0.510]
# validation epoch: 1/1000: : 308it [00:02, 166.33it/s, loss=11.321, bar=3.280, pos=2.156, token=3.608, dur=1.815, phrase=0.462]
# validation epoch: 1/1000: : 310it [00:02, 166.33it/s, loss=11.279, bar=2.787, pos=2.760, token=2.923, dur=2.401, phrase=0.408]
# validation epoch: 1/1000: : 312it [00:02, 166.33it/s, loss=9.767, bar=2.871, pos=1.947, token=3.021, dur=1.473, phrase=0.455]
# validation epoch: 1/1000: : 314it [00:02, 166.33it/s, loss=11.246, bar=3.929, pos=2.382, token=2.770, dur=1.697, phrase=0.468]
# validation epoch: 1/1000: : 316it [00:02, 166.33it/s, loss=9.392, bar=2.487, pos=1.981, token=3.172, dur=1.355, phrase=0.396]
# validation epoch: 1/1000: : 318it [00:02, 166.33it/s, loss=8.966, bar=2.536, pos=1.974, token=2.712, dur=1.348, phrase=0.397]
# validation epoch: 1/1000: : 320it [00:02, 166.33it/s, loss=9.109, bar=2.870, pos=1.895, token=2.688, dur=1.224, phrase=0.432]
# validation epoch: 1/1000: : 322it [00:02, 166.33it/s, loss=8.843, bar=2.487, pos=1.765, token=2.900, dur=1.288, phrase=0.403]
# validation epoch: 1/1000: : 324it [00:02, 166.15it/s, loss=8.843, bar=2.487, pos=1.765, token=2.900, dur=1.288, phrase=0.403]
# validation epoch: 1/1000: : 324it [00:02, 166.15it/s, loss=11.390, bar=2.958, pos=2.281, token=3.373, dur=2.234, phrase=0.545]
# validation epoch: 1/1000: : 326it [00:02, 166.15it/s, loss=9.240, bar=2.249, pos=2.175, token=3.009, dur=1.387, phrase=0.419]
# validation epoch: 1/1000: : 328it [00:02, 166.15it/s, loss=9.289, bar=2.534, pos=2.086, token=3.013, dur=1.223, phrase=0.433]
# validation epoch: 1/1000: : 330it [00:02, 166.15it/s, loss=9.808, bar=2.506, pos=1.877, token=2.928, dur=1.817, phrase=0.680]
# validation epoch: 1/1000: : 332it [00:02, 166.15it/s, loss=10.338, bar=2.853, pos=2.406, token=2.782, dur=1.873, phrase=0.423]
# validation epoch: 1/1000: : 334it [00:02, 166.15it/s, loss=10.246, bar=2.348, pos=2.463, token=2.612, dur=2.262, phrase=0.560]
# validation epoch: 1/1000: : 336it [00:02, 166.15it/s, loss=9.568, bar=2.411, pos=1.964, token=2.985, dur=1.701, phrase=0.508]
# validation epoch: 1/1000: : 338it [00:02, 166.15it/s, loss=11.090, bar=2.973, pos=2.648, token=2.761, dur=2.380, phrase=0.329]
# validation epoch: 1/1000: : 340it [00:02, 166.15it/s, loss=8.945, bar=2.207, pos=2.131, token=3.352, dur=0.924, phrase=0.330]
# validation epoch: 1/1000: : 342it [00:02, 168.17it/s, loss=8.945, bar=2.207, pos=2.131, token=3.352, dur=0.924, phrase=0.330]
# validation epoch: 1/1000: : 342it [00:02, 168.17it/s, loss=9.058, bar=2.340, pos=2.115, token=2.805, dur=1.451, phrase=0.348]
# validation epoch: 1/1000: : 344it [00:02, 168.17it/s, loss=11.242, bar=3.101, pos=2.602, token=3.406, dur=1.822, phrase=0.311]
# validation epoch: 1/1000: : 346it [00:02, 168.17it/s, loss=10.305, bar=3.143, pos=2.431, token=2.736, dur=1.573, phrase=0.422]
# validation epoch: 1/1000: : 348it [00:02, 168.17it/s, loss=9.079, bar=2.431, pos=1.663, token=3.055, dur=1.406, phrase=0.524]
# validation epoch: 1/1000: : 350it [00:02, 168.17it/s, loss=10.537, bar=3.820, pos=2.241, token=2.449, dur=1.636, phrase=0.390]
# validation epoch: 1/1000: : 352it [00:02, 168.17it/s, loss=10.732, bar=3.873, pos=2.412, token=2.650, dur=1.488, phrase=0.309]
# validation epoch: 1/1000: : 354it [00:02, 168.17it/s, loss=11.392, bar=3.556, pos=2.270, token=3.559, dur=1.570, phrase=0.437]
# validation epoch: 1/1000: : 356it [00:02, 168.17it/s, loss=10.673, bar=3.931, pos=1.974, token=3.298, dur=1.100, phrase=0.371]
# validation epoch: 1/1000: : 358it [00:02, 168.17it/s, loss=9.879, bar=2.511, pos=1.951, token=3.182, dur=1.687, phrase=0.548]
# validation epoch: 1/1000: : 360it [00:02, 171.11it/s, loss=9.879, bar=2.511, pos=1.951, token=3.182, dur=1.687, phrase=0.548]
# validation epoch: 1/1000: : 360it [00:02, 171.11it/s, loss=8.269, bar=2.300, pos=1.697, token=2.624, dur=1.231, phrase=0.416]
# validation epoch: 1/1000: : 362it [00:02, 171.11it/s, loss=13.196, bar=5.615, pos=2.054, token=2.779, dur=2.103, phrase=0.644]
# validation epoch: 1/1000: : 364it [00:02, 171.11it/s, loss=10.634, bar=3.551, pos=2.816, token=2.807, dur=1.171, phrase=0.289]
# validation epoch: 1/1000: : 366it [00:02, 171.11it/s, loss=10.634, bar=3.033, pos=2.633, token=3.042, dur=1.636, phrase=0.290]
# validation epoch: 1/1000: : 368it [00:02, 171.11it/s, loss=9.601, bar=2.533, pos=1.978, token=2.434, dur=2.214, phrase=0.442]
# validation epoch: 1/1000: : 370it [00:02, 171.11it/s, loss=10.934, bar=2.684, pos=2.569, token=3.809, dur=1.558, phrase=0.314]
# validation epoch: 1/1000: : 372it [00:02, 171.11it/s, loss=8.636, bar=2.624, pos=2.024, token=2.740, dur=0.899, phrase=0.349]
# validation epoch: 1/1000: : 374it [00:02, 171.11it/s, loss=12.375, bar=3.317, pos=2.632, token=4.468, dur=1.601, phrase=0.356]
# validation epoch: 1/1000: : 376it [00:02, 171.11it/s, loss=8.589, bar=2.333, pos=2.043, token=2.969, dur=0.917, phrase=0.327]
# validation epoch: 1/1000: : 378it [00:02, 171.11it/s, loss=10.896, bar=3.472, pos=2.393, token=2.984, dur=1.517, phrase=0.531]
# validation epoch: 1/1000: : 380it [00:02, 174.66it/s, loss=10.896, bar=3.472, pos=2.393, token=2.984, dur=1.517, phrase=0.531]
# validation epoch: 1/1000: : 380it [00:02, 174.66it/s, loss=9.661, bar=2.722, pos=2.244, token=2.859, dur=1.420, phrase=0.416]
# validation epoch: 1/1000: : 382it [00:02, 174.66it/s, loss=10.173, bar=2.498, pos=2.176, token=3.043, dur=1.967, phrase=0.488]
# validation epoch: 1/1000: : 386it [00:02, 137.24it/s, loss=9.074, bar=2.361, pos=2.198, token=2.687, dur=1.367, phrase=0.460]
# training epoch: 2/1000:   0%|                                                                                                | 0/1545 [00:00<?, ?it/s]
# Validation loss decreased (inf --> 10.224549).  Saving model ...
# Training Runinng Loss = 13.8567897037395, Validation Running Loss = 10.224548517731188
# training epoch: 2/1000: : 3090it [00:43, 71.26it/s, loss=7.662, bar=1.454, pos=1.701, token=2.408, dur=1.795, phrase=0.304]
#
#   0%|                                                                                                                         | 0/193 [00:00<?, ?it/s]
# validation epoch: 2/1000:   0%|                                                                                               | 0/193 [00:00<?, ?it/s]
# validation epoch: 2/1000:   0%|                       | 0/193 [00:00<?, ?it/s, loss=9.238, bar=2.581, pos=1.936, token=3.006, dur=1.420, phrase=0.295]
# validation epoch: 2/1000:   1%|▏              | 2/193 [00:00<00:33,  5.69it/s, loss=9.238, bar=2.581, pos=1.936, token=3.006, dur=1.420, phrase=0.295]
# validation epoch: 2/1000:   1%|▏              | 2/193 [00:00<00:33,  5.69it/s, loss=6.542, bar=1.460, pos=1.020, token=2.509, dur=1.169, phrase=0.384]
# validation epoch: 2/1000:   2%|▎              | 4/193 [00:00<00:33,  5.69it/s, loss=7.883, bar=1.365, pos=1.802, token=2.562, dur=1.583, phrase=0.569]
# validation epoch: 2/1000:   3%|▍              | 6/193 [00:00<00:32,  5.69it/s, loss=8.686, bar=2.024, pos=1.950, token=2.237, dur=1.992, phrase=0.483]
# validation epoch: 2/1000:   4%|▌              | 8/193 [00:00<00:32,  5.69it/s, loss=9.825, bar=3.508, pos=1.942, token=2.281, dur=1.672, phrase=0.422]
# validation epoch: 2/1000:   5%|▋             | 10/193 [00:00<00:32,  5.69it/s, loss=7.020, bar=1.747, pos=1.384, token=2.357, dur=1.184, phrase=0.348]
# validation epoch: 2/1000:   6%|▊             | 12/193 [00:00<00:31,  5.69it/s, loss=8.993, bar=1.570, pos=1.589, token=3.460, dur=1.923, phrase=0.451]
# validation epoch: 2/1000:   7%|█             | 14/193 [00:00<00:31,  5.69it/s, loss=9.131, bar=2.065, pos=1.857, token=2.816, dur=1.994, phrase=0.399]
# validation epoch: 2/1000:   8%|█            | 16/193 [00:00<00:31,  5.69it/s, loss=10.891, bar=4.000, pos=1.317, token=3.342, dur=1.687, phrase=0.545]
# validation epoch: 2/1000:   9%|█▏           | 18/193 [00:00<00:03, 49.10it/s, loss=10.891, bar=4.000, pos=1.317, token=3.342, dur=1.687, phrase=0.545]
# validation epoch: 2/1000:   9%|█▎            | 18/193 [00:00<00:03, 49.10it/s, loss=7.924, bar=1.476, pos=1.343, token=3.230, dur=1.426, phrase=0.449]
# validation epoch: 2/1000:  10%|█▍            | 20/193 [00:00<00:03, 49.10it/s, loss=6.133, bar=1.306, pos=0.850, token=2.305, dur=1.174, phrase=0.499]
# validation epoch: 2/1000:  11%|█▌            | 22/193 [00:00<00:03, 49.10it/s, loss=6.193, bar=1.173, pos=1.232, token=2.229, dur=1.112, phrase=0.446]
# validation epoch: 2/1000:  12%|█▋            | 24/193 [00:00<00:03, 49.10it/s, loss=5.593, bar=1.000, pos=0.928, token=2.014, dur=1.343, phrase=0.307]
# validation epoch: 2/1000:  13%|█▉            | 26/193 [00:00<00:03, 49.10it/s, loss=8.121, bar=2.372, pos=1.541, token=2.447, dur=1.420, phrase=0.341]
# validation epoch: 2/1000:  15%|██            | 28/193 [00:00<00:03, 49.10it/s, loss=8.051, bar=1.730, pos=1.533, token=3.163, dur=1.350, phrase=0.276]
# validation epoch: 2/1000:  16%|██▏           | 30/193 [00:00<00:03, 49.10it/s, loss=7.869, bar=2.251, pos=1.956, token=2.284, dur=1.108, phrase=0.270]
# validation epoch: 2/1000:  17%|██▎           | 32/193 [00:00<00:03, 49.10it/s, loss=7.690, bar=1.363, pos=1.731, token=2.463, dur=1.764, phrase=0.369]
# validation epoch: 2/1000:  18%|██▍           | 34/193 [00:00<00:03, 49.10it/s, loss=6.565, bar=1.448, pos=0.972, token=2.227, dur=1.420, phrase=0.498]
# validation epoch: 2/1000:  19%|██▌           | 36/193 [00:00<00:03, 49.10it/s, loss=7.093, bar=1.480, pos=1.399, token=2.376, dur=1.512, phrase=0.326]
# validation epoch: 2/1000:  20%|██▊           | 38/193 [00:00<00:03, 49.10it/s, loss=6.749, bar=1.859, pos=0.815, token=2.508, dur=1.143, phrase=0.425]
# validation epoch: 2/1000:  21%|██▉           | 40/193 [00:00<00:01, 95.89it/s, loss=6.749, bar=1.859, pos=0.815, token=2.508, dur=1.143, phrase=0.425]
# validation epoch: 2/1000:  21%|██▉           | 40/193 [00:00<00:01, 95.89it/s, loss=6.592, bar=1.401, pos=1.236, token=2.285, dur=1.282, phrase=0.388]
# validation epoch: 2/1000:  22%|███           | 42/193 [00:00<00:01, 95.89it/s, loss=7.785, bar=1.641, pos=2.039, token=2.442, dur=1.365, phrase=0.299]
# validation epoch: 2/1000:  23%|███▏          | 44/193 [00:00<00:01, 95.89it/s, loss=8.193, bar=3.071, pos=1.216, token=2.247, dur=1.245, phrase=0.415]
# validation epoch: 2/1000:  24%|███▎          | 46/193 [00:00<00:01, 95.89it/s, loss=7.001, bar=1.454, pos=1.266, token=2.398, dur=1.587, phrase=0.296]
# validation epoch: 2/1000:  25%|███▍          | 48/193 [00:00<00:01, 95.89it/s, loss=6.807, bar=1.639, pos=1.044, token=2.214, dur=1.420, phrase=0.488]
# validation epoch: 2/1000:  26%|███▋          | 50/193 [00:00<00:01, 95.89it/s, loss=8.959, bar=1.681, pos=2.152, token=2.481, dur=2.239, phrase=0.406]
# validation epoch: 2/1000:  27%|███▊          | 52/193 [00:00<00:01, 95.89it/s, loss=8.198, bar=1.903, pos=1.820, token=2.778, dur=1.362, phrase=0.335]
# validation epoch: 2/1000:  28%|███▉          | 54/193 [00:00<00:01, 95.89it/s, loss=8.679, bar=2.413, pos=1.266, token=3.217, dur=1.440, phrase=0.344]
# validation epoch: 2/1000:  29%|████          | 56/193 [00:00<00:01, 95.89it/s, loss=9.905, bar=3.204, pos=1.754, token=2.398, dur=2.097, phrase=0.451]
# validation epoch: 2/1000:  30%|███▉         | 58/193 [00:00<00:01, 118.67it/s, loss=9.905, bar=3.204, pos=1.754, token=2.398, dur=2.097, phrase=0.451]
# validation epoch: 2/1000:  30%|███▉         | 58/193 [00:00<00:01, 118.67it/s, loss=8.247, bar=2.367, pos=1.436, token=2.318, dur=1.591, phrase=0.535]
# validation epoch: 2/1000:  31%|████         | 60/193 [00:00<00:01, 118.67it/s, loss=8.095, bar=1.514, pos=1.651, token=3.229, dur=1.387, phrase=0.314]
# validation epoch: 2/1000:  32%|████▏        | 62/193 [00:00<00:01, 118.67it/s, loss=8.196, bar=2.017, pos=1.572, token=2.750, dur=1.436, phrase=0.420]
# validation epoch: 2/1000:  33%|████▎        | 64/193 [00:00<00:01, 118.67it/s, loss=5.929, bar=1.657, pos=1.121, token=2.007, dur=0.886, phrase=0.258]
# validation epoch: 2/1000:  34%|████▍        | 66/193 [00:00<00:01, 118.67it/s, loss=7.534, bar=1.444, pos=1.472, token=3.037, dur=1.190, phrase=0.392]
# validation epoch: 2/1000:  35%|████▌        | 68/193 [00:00<00:01, 118.67it/s, loss=8.126, bar=2.505, pos=1.494, token=2.332, dur=1.434, phrase=0.361]
# validation epoch: 2/1000:  36%|████▋        | 70/193 [00:00<00:01, 118.67it/s, loss=8.167, bar=1.699, pos=1.487, token=2.762, dur=1.714, phrase=0.506]
# validation epoch: 2/1000:  37%|████▊        | 72/193 [00:00<00:01, 118.67it/s, loss=9.646, bar=2.453, pos=1.524, token=3.778, dur=1.487, phrase=0.404]
# validation epoch: 2/1000:  38%|████▉        | 74/193 [00:00<00:01, 118.67it/s, loss=8.554, bar=2.077, pos=1.806, token=2.601, dur=1.660, phrase=0.410]
# validation epoch: 2/1000:  39%|█████        | 76/193 [00:00<00:00, 134.35it/s, loss=8.554, bar=2.077, pos=1.806, token=2.601, dur=1.660, phrase=0.410]
# validation epoch: 2/1000:  39%|█████        | 76/193 [00:00<00:00, 134.35it/s, loss=6.509, bar=1.592, pos=1.007, token=2.099, dur=1.528, phrase=0.283]
# validation epoch: 2/1000:  40%|█████▎       | 78/193 [00:00<00:00, 134.35it/s, loss=7.675, bar=1.547, pos=1.269, token=2.657, dur=1.756, phrase=0.446]
# validation epoch: 2/1000:  41%|█████▍       | 80/193 [00:00<00:00, 134.35it/s, loss=6.521, bar=1.556, pos=0.874, token=2.436, dur=1.227, phrase=0.428]
# validation epoch: 2/1000:  42%|█████▌       | 82/193 [00:00<00:00, 134.35it/s, loss=8.091, bar=2.838, pos=1.332, token=2.198, dur=1.421, phrase=0.301]
# validation epoch: 2/1000:  44%|█████▋       | 84/193 [00:00<00:00, 134.35it/s, loss=6.505, bar=1.581, pos=0.975, token=2.415, dur=1.122, phrase=0.413]
# validation epoch: 2/1000:  45%|█████▊       | 86/193 [00:00<00:00, 134.35it/s, loss=6.839, bar=2.317, pos=0.969, token=2.316, dur=0.982, phrase=0.255]
# validation epoch: 2/1000:  46%|█████▉       | 88/193 [00:00<00:00, 134.35it/s, loss=8.730, bar=2.018, pos=1.646, token=2.702, dur=1.859, phrase=0.506]
# validation epoch: 2/1000:  47%|██████       | 90/193 [00:00<00:00, 134.35it/s, loss=6.868, bar=1.436, pos=1.103, token=2.567, dur=1.397, phrase=0.364]
# validation epoch: 2/1000:  48%|██████▏      | 92/193 [00:00<00:00, 134.35it/s, loss=9.827, bar=2.497, pos=1.795, token=2.576, dur=2.475, phrase=0.482]
# validation epoch: 2/1000:  49%|██████▎      | 94/193 [00:00<00:00, 141.51it/s, loss=9.827, bar=2.497, pos=1.795, token=2.576, dur=2.475, phrase=0.482]
# validation epoch: 2/1000:  49%|██████▎      | 94/193 [00:00<00:00, 141.51it/s, loss=7.799, bar=1.984, pos=1.565, token=2.325, dur=1.444, phrase=0.482]
# validation epoch: 2/1000:  50%|██████▍      | 96/193 [00:00<00:00, 141.51it/s, loss=7.897, bar=1.403, pos=1.220, token=3.496, dur=1.385, phrase=0.393]
# validation epoch: 2/1000:  51%|██████▌      | 98/193 [00:00<00:00, 141.51it/s, loss=6.280, bar=1.369, pos=0.897, token=2.594, dur=1.021, phrase=0.398]
# validation epoch: 2/1000:  52%|██████▏     | 100/193 [00:00<00:00, 141.51it/s, loss=6.689, bar=1.577, pos=1.105, token=2.235, dur=1.346, phrase=0.425]
# validation epoch: 2/1000:  53%|██████▎     | 102/193 [00:00<00:00, 141.51it/s, loss=7.708, bar=2.203, pos=1.360, token=2.340, dur=1.441, phrase=0.364]
# validation epoch: 2/1000:  54%|██████▍     | 104/193 [00:00<00:00, 141.51it/s, loss=9.262, bar=1.427, pos=1.330, token=4.573, dur=1.546, phrase=0.386]
# validation epoch: 2/1000:  55%|██████▌     | 106/193 [00:00<00:00, 141.51it/s, loss=7.980, bar=2.553, pos=1.132, token=2.493, dur=1.314, phrase=0.487]
# validation epoch: 2/1000:  56%|██████▋     | 108/193 [00:00<00:00, 141.51it/s, loss=7.238, bar=1.778, pos=1.083, token=2.720, dur=1.292, phrase=0.364]
# validation epoch: 2/1000:  57%|██████▊     | 110/193 [00:01<00:00, 141.51it/s, loss=8.037, bar=1.779, pos=1.370, token=2.800, dur=1.634, phrase=0.454]
# validation epoch: 2/1000:  58%|██████▉     | 112/193 [00:01<00:00, 148.07it/s, loss=8.037, bar=1.779, pos=1.370, token=2.800, dur=1.634, phrase=0.454]
# validation epoch: 2/1000:  58%|██████▉     | 112/193 [00:01<00:00, 148.07it/s, loss=8.569, bar=2.617, pos=1.388, token=2.679, dur=1.435, phrase=0.451]
# validation epoch: 2/1000:  59%|███████     | 114/193 [00:01<00:00, 148.07it/s, loss=8.330, bar=2.078, pos=1.596, token=2.807, dur=1.503, phrase=0.347]
# validation epoch: 2/1000:  60%|███████▏    | 116/193 [00:01<00:00, 148.07it/s, loss=7.305, bar=2.309, pos=1.083, token=2.276, dur=1.239, phrase=0.398]
# validation epoch: 2/1000:  61%|███████▎    | 118/193 [00:01<00:00, 148.07it/s, loss=5.932, bar=1.430, pos=1.029, token=2.009, dur=1.020, phrase=0.445]
# validation epoch: 2/1000:  62%|███████▍    | 120/193 [00:01<00:00, 148.07it/s, loss=8.429, bar=1.541, pos=1.891, token=2.685, dur=1.919, phrase=0.393]
# validation epoch: 2/1000:  63%|███████▌    | 122/193 [00:01<00:00, 148.07it/s, loss=7.077, bar=1.529, pos=1.577, token=2.337, dur=1.275, phrase=0.358]
# validation epoch: 2/1000:  64%|███████▋    | 124/193 [00:01<00:00, 148.07it/s, loss=8.164, bar=1.170, pos=1.750, token=2.722, dur=2.040, phrase=0.482]
# validation epoch: 2/1000:  65%|███████▊    | 126/193 [00:01<00:00, 148.07it/s, loss=8.523, bar=3.376, pos=1.133, token=2.266, dur=1.354, phrase=0.395]
# validation epoch: 2/1000:  66%|███████▉    | 128/193 [00:01<00:00, 148.07it/s, loss=7.883, bar=1.575, pos=1.929, token=2.258, dur=1.579, phrase=0.543]
# validation epoch: 2/1000:  67%|████████    | 130/193 [00:01<00:00, 155.36it/s, loss=7.883, bar=1.575, pos=1.929, token=2.258, dur=1.579, phrase=0.543]
# validation epoch: 2/1000:  67%|████████    | 130/193 [00:01<00:00, 155.36it/s, loss=9.676, bar=2.683, pos=1.875, token=2.547, dur=2.094, phrase=0.478]
# validation epoch: 2/1000:  68%|████████▏   | 132/193 [00:01<00:00, 155.36it/s, loss=8.800, bar=2.747, pos=1.420, token=2.518, dur=1.738, phrase=0.377]
# validation epoch: 2/1000:  69%|████████▎   | 134/193 [00:01<00:00, 155.36it/s, loss=7.511, bar=1.642, pos=1.750, token=2.242, dur=1.493, phrase=0.385]
# validation epoch: 2/1000:  70%|███████▊   | 136/193 [00:01<00:00, 155.36it/s, loss=10.545, bar=2.398, pos=2.410, token=2.451, dur=2.834, phrase=0.451]
# validation epoch: 2/1000:  72%|████████▌   | 138/193 [00:01<00:00, 155.36it/s, loss=8.618, bar=2.381, pos=1.958, token=2.398, dur=1.496, phrase=0.385]
# validation epoch: 2/1000:  73%|████████▋   | 140/193 [00:01<00:00, 155.36it/s, loss=8.895, bar=2.460, pos=1.465, token=2.579, dur=1.854, phrase=0.538]
# validation epoch: 2/1000:  74%|████████▊   | 142/193 [00:01<00:00, 155.36it/s, loss=6.775, bar=1.537, pos=1.176, token=2.496, dur=1.146, phrase=0.419]
# validation epoch: 2/1000:  75%|████████▉   | 144/193 [00:01<00:00, 155.36it/s, loss=5.823, bar=1.596, pos=0.904, token=2.037, dur=0.966, phrase=0.319]
# validation epoch: 2/1000:  76%|█████████   | 146/193 [00:01<00:00, 155.36it/s, loss=8.329, bar=2.421, pos=1.960, token=2.320, dur=1.310, phrase=0.317]
# validation epoch: 2/1000:  77%|█████████▏  | 148/193 [00:01<00:00, 161.20it/s, loss=8.329, bar=2.421, pos=1.960, token=2.320, dur=1.310, phrase=0.317]
# validation epoch: 2/1000:  77%|█████████▏  | 148/193 [00:01<00:00, 161.20it/s, loss=7.874, bar=1.659, pos=1.496, token=2.703, dur=1.589, phrase=0.428]
# validation epoch: 2/1000:  78%|█████████▎  | 150/193 [00:01<00:00, 161.20it/s, loss=8.570, bar=1.604, pos=1.485, token=2.621, dur=2.293, phrase=0.567]
# validation epoch: 2/1000:  79%|█████████▍  | 152/193 [00:01<00:00, 161.20it/s, loss=8.468, bar=1.244, pos=1.767, token=3.336, dur=1.736, phrase=0.385]
# validation epoch: 2/1000:  80%|█████████▌  | 154/193 [00:01<00:00, 161.20it/s, loss=6.571, bar=1.864, pos=1.064, token=2.142, dur=1.115, phrase=0.386]
# validation epoch: 2/1000:  81%|█████████▋  | 156/193 [00:01<00:00, 161.20it/s, loss=7.671, bar=2.078, pos=1.503, token=2.355, dur=1.488, phrase=0.247]
# validation epoch: 2/1000:  82%|█████████▊  | 158/193 [00:01<00:00, 161.20it/s, loss=6.108, bar=1.173, pos=1.326, token=2.133, dur=1.147, phrase=0.329]
# validation epoch: 2/1000:  83%|█████████▉  | 160/193 [00:01<00:00, 161.20it/s, loss=8.123, bar=1.515, pos=1.714, token=2.776, dur=1.634, phrase=0.483]
# validation epoch: 2/1000:  84%|██████████  | 162/193 [00:01<00:00, 161.20it/s, loss=6.855, bar=1.251, pos=1.462, token=2.369, dur=1.410, phrase=0.363]
# validation epoch: 2/1000:  85%|██████████▏ | 164/193 [00:01<00:00, 161.20it/s, loss=6.529, bar=1.396, pos=1.080, token=2.309, dur=1.452, phrase=0.292]
# validation epoch: 2/1000:  86%|██████████▎ | 166/193 [00:01<00:00, 165.99it/s, loss=6.529, bar=1.396, pos=1.080, token=2.309, dur=1.452, phrase=0.292]
# validation epoch: 2/1000:  86%|██████████▎ | 166/193 [00:01<00:00, 165.99it/s, loss=7.622, bar=1.372, pos=2.047, token=2.161, dur=1.676, phrase=0.367]
# validation epoch: 2/1000:  87%|██████████▍ | 168/193 [00:01<00:00, 165.99it/s, loss=7.159, bar=1.502, pos=1.828, token=2.327, dur=1.175, phrase=0.328]
# validation epoch: 2/1000:  88%|██████████▌ | 170/193 [00:01<00:00, 165.99it/s, loss=7.251, bar=1.545, pos=1.096, token=2.540, dur=1.642, phrase=0.429]
# validation epoch: 2/1000:  89%|██████████▋ | 172/193 [00:01<00:00, 165.99it/s, loss=7.857, bar=1.569, pos=1.722, token=2.261, dur=1.891, phrase=0.413]
# validation epoch: 2/1000:  90%|██████████▊ | 174/193 [00:01<00:00, 165.99it/s, loss=6.700, bar=1.895, pos=1.089, token=2.248, dur=1.052, phrase=0.416]
# validation epoch: 2/1000:  91%|██████████ | 176/193 [00:01<00:00, 165.99it/s, loss=11.042, bar=4.403, pos=2.137, token=2.636, dur=1.447, phrase=0.419]
# validation epoch: 2/1000:  92%|███████████ | 178/193 [00:01<00:00, 165.99it/s, loss=8.488, bar=2.673, pos=1.185, token=2.893, dur=1.337, phrase=0.400]
# validation epoch: 2/1000:  93%|███████████▏| 180/193 [00:01<00:00, 165.99it/s, loss=8.133, bar=1.917, pos=1.330, token=2.774, dur=1.648, phrase=0.464]
# validation epoch: 2/1000:  94%|███████████▎| 182/193 [00:01<00:00, 165.99it/s, loss=7.053, bar=1.682, pos=1.147, token=2.539, dur=1.231, phrase=0.455]
# validation epoch: 2/1000:  95%|███████████▍| 184/193 [00:01<00:00, 169.31it/s, loss=7.053, bar=1.682, pos=1.147, token=2.539, dur=1.231, phrase=0.455]
# validation epoch: 2/1000:  95%|███████████▍| 184/193 [00:01<00:00, 169.31it/s, loss=6.523, bar=1.561, pos=1.517, token=2.052, dur=1.076, phrase=0.318]
# validation epoch: 2/1000:  96%|███████████▌| 186/193 [00:01<00:00, 169.31it/s, loss=7.523, bar=1.636, pos=1.771, token=2.307, dur=1.480, phrase=0.329]
# validation epoch: 2/1000:  97%|███████████▋| 188/193 [00:01<00:00, 169.31it/s, loss=8.021, bar=1.688, pos=1.341, token=3.196, dur=1.331, phrase=0.465]
# validation epoch: 2/1000:  98%|███████████▊| 190/193 [00:01<00:00, 169.31it/s, loss=8.499, bar=2.133, pos=1.658, token=2.555, dur=1.782, phrase=0.371]
# validation epoch: 2/1000:  99%|███████████▉| 192/193 [00:01<00:00, 169.31it/s, loss=7.069, bar=1.325, pos=1.385, token=2.412, dur=1.542, phrase=0.405]
# validation epoch: 2/1000: : 194it [00:01, 169.31it/s, loss=8.015, bar=2.070, pos=1.552, token=2.325, dur=1.795, phrase=0.274]
# ...
# validation epoch: 12/1000:  89%|█████████▊ | 172/193 [00:01<00:00, 160.72it/s, loss=7.857, bar=1.569, pos=1.722, token=2.261, dur=1.891, phrase=0.413]
# validation epoch: 12/1000:  90%|█████████▉ | 174/193 [00:01<00:00, 160.72it/s, loss=6.700, bar=1.895, pos=1.089, token=2.248, dur=1.052, phrase=0.416]
# validation epoch: 12/1000:  91%|█████████ | 176/193 [00:01<00:00, 160.72it/s, loss=11.042, bar=4.403, pos=2.137, token=2.636, dur=1.447, phrase=0.419]
# validation epoch: 12/1000:  92%|██████████▏| 178/193 [00:01<00:00, 160.72it/s, loss=8.488, bar=2.673, pos=1.185, token=2.893, dur=1.337, phrase=0.400]
# validation epoch: 12/1000:  93%|██████████▎| 180/193 [00:01<00:00, 160.72it/s, loss=8.133, bar=1.917, pos=1.330, token=2.774, dur=1.648, phrase=0.464]
# validation epoch: 12/1000:  94%|██████████▎| 182/193 [00:01<00:00, 161.43it/s, loss=8.133, bar=1.917, pos=1.330, token=2.774, dur=1.648, phrase=0.464]
# validation epoch: 12/1000:  94%|██████████▎| 182/193 [00:01<00:00, 161.43it/s, loss=7.053, bar=1.682, pos=1.147, token=2.539, dur=1.231, phrase=0.455]
# validation epoch: 12/1000:  95%|██████████▍| 184/193 [00:01<00:00, 161.43it/s, loss=6.523, bar=1.561, pos=1.517, token=2.052, dur=1.076, phrase=0.318]
# validation epoch: 12/1000:  96%|██████████▌| 186/193 [00:01<00:00, 161.43it/s, loss=7.523, bar=1.636, pos=1.771, token=2.307, dur=1.480, phrase=0.329]
# validation epoch: 12/1000:  97%|██████████▋| 188/193 [00:01<00:00, 161.43it/s, loss=8.021, bar=1.688, pos=1.341, token=3.196, dur=1.331, phrase=0.465]
# validation epoch: 12/1000:  98%|██████████▊| 190/193 [00:01<00:00, 161.43it/s, loss=8.499, bar=2.133, pos=1.658, token=2.555, dur=1.782, phrase=0.371]
# validation epoch: 12/1000:  99%|██████████▉| 192/193 [00:01<00:00, 161.43it/s, loss=7.069, bar=1.325, pos=1.385, token=2.412, dur=1.542, phrase=0.405]
# validation epoch: 12/1000: : 194it [00:01, 161.43it/s, loss=8.015, bar=2.070, pos=1.552, token=2.325, dur=1.795, phrase=0.274]
# validation epoch: 12/1000: : 196it [00:01, 161.43it/s, loss=7.325, bar=2.588, pos=0.920, token=2.320, dur=1.162, phrase=0.335]
# validation epoch: 12/1000: : 198it [00:01, 161.43it/s, loss=7.592, bar=2.678, pos=0.977, token=2.206, dur=1.290, phrase=0.441]
# validation epoch: 12/1000: : 200it [00:01, 161.48it/s, loss=7.592, bar=2.678, pos=0.977, token=2.206, dur=1.290, phrase=0.441]
# validation epoch: 12/1000: : 200it [00:01, 161.48it/s, loss=7.661, bar=1.977, pos=1.479, token=2.050, dur=1.760, phrase=0.394]
# validation epoch: 12/1000: : 202it [00:01, 161.48it/s, loss=8.433, bar=1.554, pos=1.837, token=2.406, dur=2.262, phrase=0.374]
# validation epoch: 12/1000: : 204it [00:01, 161.48it/s, loss=8.406, bar=1.885, pos=1.983, token=2.215, dur=1.858, phrase=0.465]
# validation epoch: 12/1000: : 206it [00:01, 161.48it/s, loss=7.921, bar=1.530, pos=1.483, token=2.611, dur=1.814, phrase=0.482]
# validation epoch: 12/1000: : 208it [00:01, 161.48it/s, loss=6.250, bar=1.255, pos=0.947, token=2.617, dur=1.066, phrase=0.365]
# validation epoch: 12/1000: : 210it [00:01, 161.48it/s, loss=7.521, bar=1.850, pos=1.347, token=2.465, dur=1.440, phrase=0.418]
# validation epoch: 12/1000: : 212it [00:01, 161.48it/s, loss=7.570, bar=2.448, pos=1.262, token=2.181, dur=1.329, phrase=0.351]
# validation epoch: 12/1000: : 214it [00:01, 161.48it/s, loss=7.463, bar=2.312, pos=1.404, token=1.991, dur=1.436, phrase=0.321]
# validation epoch: 12/1000: : 216it [00:01, 161.48it/s, loss=6.540, bar=1.546, pos=1.089, token=2.087, dur=1.438, phrase=0.380]
# validation epoch: 12/1000: : 218it [00:01, 161.52it/s, loss=6.540, bar=1.546, pos=1.089, token=2.087, dur=1.438, phrase=0.380]
# validation epoch: 12/1000: : 218it [00:01, 161.52it/s, loss=8.093, bar=1.574, pos=1.916, token=2.718, dur=1.610, phrase=0.275]
# validation epoch: 12/1000: : 220it [00:01, 161.52it/s, loss=7.088, bar=1.732, pos=0.969, token=2.227, dur=1.723, phrase=0.439]
# validation epoch: 12/1000: : 222it [00:01, 161.52it/s, loss=8.810, bar=2.720, pos=1.239, token=2.638, dur=1.704, phrase=0.509]
# validation epoch: 12/1000: : 224it [00:01, 161.52it/s, loss=7.392, bar=2.411, pos=1.084, token=2.360, dur=1.213, phrase=0.324]
# validation epoch: 12/1000: : 226it [00:01, 161.52it/s, loss=7.136, bar=1.426, pos=1.401, token=2.267, dur=1.605, phrase=0.438]
# validation epoch: 12/1000: : 228it [00:01, 161.52it/s, loss=7.287, bar=2.272, pos=1.132, token=2.259, dur=1.168, phrase=0.455]
# validation epoch: 12/1000: : 230it [00:01, 161.52it/s, loss=8.039, bar=2.326, pos=1.671, token=2.262, dur=1.430, phrase=0.350]
# validation epoch: 12/1000: : 232it [00:01, 161.52it/s, loss=9.356, bar=3.002, pos=1.361, token=2.863, dur=1.676, phrase=0.454]
# validation epoch: 12/1000: : 234it [00:01, 161.52it/s, loss=9.603, bar=1.408, pos=2.046, token=2.827, dur=2.762, phrase=0.560]
# validation epoch: 12/1000: : 236it [00:01, 163.07it/s, loss=9.603, bar=1.408, pos=2.046, token=2.827, dur=2.762, phrase=0.560]
# validation epoch: 12/1000: : 236it [00:01, 163.07it/s, loss=9.111, bar=2.553, pos=1.499, token=2.746, dur=1.852, phrase=0.462]
# validation epoch: 12/1000: : 238it [00:01, 163.07it/s, loss=7.163, bar=1.491, pos=1.311, token=2.303, dur=1.651, phrase=0.406]
# validation epoch: 12/1000: : 240it [00:01, 163.07it/s, loss=7.779, bar=1.419, pos=1.435, token=2.233, dur=2.151, phrase=0.540]
# validation epoch: 12/1000: : 242it [00:01, 163.07it/s, loss=7.291, bar=1.536, pos=1.785, token=2.232, dur=1.399, phrase=0.339]
# validation epoch: 12/1000: : 244it [00:01, 163.07it/s, loss=9.357, bar=1.650, pos=1.628, token=4.103, dur=1.624, phrase=0.352]
# validation epoch: 12/1000: : 246it [00:01, 163.07it/s, loss=7.680, bar=2.072, pos=1.279, token=2.397, dur=1.432, phrase=0.501]
# validation epoch: 12/1000: : 248it [00:01, 163.07it/s, loss=7.637, bar=1.545, pos=1.490, token=2.416, dur=1.744, phrase=0.443]
# validation epoch: 12/1000: : 250it [00:01, 163.07it/s, loss=8.616, bar=1.825, pos=1.927, token=2.575, dur=1.841, phrase=0.448]
# validation epoch: 12/1000: : 252it [00:01, 163.07it/s, loss=7.654, bar=2.365, pos=1.351, token=2.185, dur=1.311, phrase=0.442]
# validation epoch: 12/1000: : 254it [00:01, 163.99it/s, loss=7.654, bar=2.365, pos=1.351, token=2.185, dur=1.311, phrase=0.442]
# validation epoch: 12/1000: : 254it [00:01, 163.99it/s, loss=8.847, bar=2.391, pos=1.856, token=2.628, dur=1.661, phrase=0.311]
# validation epoch: 12/1000: : 256it [00:01, 163.99it/s, loss=7.808, bar=2.527, pos=1.177, token=2.358, dur=1.312, phrase=0.433]
# validation epoch: 12/1000: : 258it [00:01, 163.99it/s, loss=7.859, bar=1.714, pos=2.020, token=2.317, dur=1.439, phrase=0.369]
# validation epoch: 12/1000: : 260it [00:01, 163.99it/s, loss=7.557, bar=2.227, pos=1.217, token=2.243, dur=1.408, phrase=0.461]
# validation epoch: 12/1000: : 262it [00:01, 163.99it/s, loss=9.085, bar=2.316, pos=1.042, token=3.968, dur=1.307, phrase=0.452]
# validation epoch: 12/1000: : 264it [00:01, 163.99it/s, loss=6.847, bar=1.432, pos=1.753, token=2.168, dur=1.179, phrase=0.316]
# validation epoch: 12/1000: : 266it [00:01, 163.99it/s, loss=7.602, bar=2.180, pos=1.168, token=2.560, dur=1.228, phrase=0.465]
# validation epoch: 12/1000: : 268it [00:01, 163.99it/s, loss=8.263, bar=1.445, pos=1.725, token=2.672, dur=1.906, phrase=0.515]
# validation epoch: 12/1000: : 270it [00:01, 163.99it/s, loss=9.171, bar=2.295, pos=2.199, token=2.340, dur=1.898, phrase=0.439]
# validation epoch: 12/1000: : 272it [00:01, 165.54it/s, loss=9.171, bar=2.295, pos=2.199, token=2.340, dur=1.898, phrase=0.439]
# validation epoch: 12/1000: : 272it [00:01, 165.54it/s, loss=7.288, bar=1.676, pos=1.192, token=2.274, dur=1.766, phrase=0.380]
# validation epoch: 12/1000: : 274it [00:01, 165.54it/s, loss=8.509, bar=1.503, pos=1.753, token=2.796, dur=1.983, phrase=0.473]
# validation epoch: 12/1000: : 276it [00:01, 165.54it/s, loss=7.541, bar=2.001, pos=1.213, token=2.526, dur=1.378, phrase=0.423]
# validation epoch: 12/1000: : 278it [00:01, 165.54it/s, loss=6.758, bar=1.680, pos=1.158, token=2.289, dur=1.282, phrase=0.349]
# validation epoch: 12/1000: : 280it [00:01, 165.54it/s, loss=6.806, bar=1.570, pos=1.215, token=2.494, dur=1.049, phrase=0.478]
# validation epoch: 12/1000: : 282it [00:01, 165.54it/s, loss=6.619, bar=1.463, pos=1.063, token=2.437, dur=1.224, phrase=0.432]
# validation epoch: 12/1000: : 284it [00:02, 165.54it/s, loss=6.935, bar=1.567, pos=1.915, token=1.988, dur=1.194, phrase=0.271]
# validation epoch: 12/1000: : 286it [00:02, 165.54it/s, loss=8.137, bar=1.834, pos=1.318, token=3.095, dur=1.568, phrase=0.322]
# validation epoch: 12/1000: : 288it [00:02, 165.54it/s, loss=6.291, bar=1.596, pos=0.972, token=2.446, dur=0.927, phrase=0.349]
# validation epoch: 12/1000: : 290it [00:02, 165.54it/s, loss=8.468, bar=3.184, pos=1.084, token=2.644, dur=1.168, phrase=0.388]
# validation epoch: 12/1000: : 292it [00:02, 170.52it/s, loss=8.468, bar=3.184, pos=1.084, token=2.644, dur=1.168, phrase=0.388]
# validation epoch: 12/1000: : 292it [00:02, 170.52it/s, loss=9.213, bar=2.412, pos=1.738, token=2.830, dur=1.788, phrase=0.444]
# validation epoch: 12/1000: : 294it [00:02, 170.52it/s, loss=6.350, bar=1.389, pos=0.908, token=2.501, dur=1.199, phrase=0.354]
# validation epoch: 12/1000: : 296it [00:02, 170.52it/s, loss=7.257, bar=1.661, pos=1.103, token=2.647, dur=1.418, phrase=0.428]
# validation epoch: 12/1000: : 298it [00:02, 170.52it/s, loss=8.060, bar=1.792, pos=1.190, token=3.415, dur=1.231, phrase=0.433]
# validation epoch: 12/1000: : 300it [00:02, 170.52it/s, loss=9.799, bar=1.269, pos=1.544, token=5.015, dur=1.539, phrase=0.432]
# validation epoch: 12/1000: : 302it [00:02, 170.52it/s, loss=7.336, bar=1.225, pos=1.398, token=2.602, dur=1.634, phrase=0.478]
# validation epoch: 12/1000: : 304it [00:02, 170.52it/s, loss=6.716, bar=1.622, pos=0.982, token=2.309, dur=1.419, phrase=0.384]
# validation epoch: 12/1000: : 306it [00:02, 170.52it/s, loss=7.801, bar=2.097, pos=1.192, token=2.472, dur=1.549, phrase=0.490]
# validation epoch: 12/1000: : 308it [00:02, 170.52it/s, loss=8.741, bar=2.289, pos=1.304, token=3.065, dur=1.645, phrase=0.438]
# validation epoch: 12/1000: : 310it [00:02, 170.52it/s, loss=8.906, bar=1.898, pos=2.044, token=2.523, dur=2.041, phrase=0.401]
# validation epoch: 12/1000: : 312it [00:02, 174.10it/s, loss=8.906, bar=1.898, pos=2.044, token=2.523, dur=2.041, phrase=0.401]
# validation epoch: 12/1000: : 312it [00:02, 174.10it/s, loss=7.175, bar=1.997, pos=1.082, token=2.389, dur=1.292, phrase=0.414]
# validation epoch: 12/1000: : 314it [00:02, 174.10it/s, loss=8.966, bar=2.987, pos=1.577, token=2.371, dur=1.572, phrase=0.458]
# validation epoch: 12/1000: : 316it [00:02, 174.10it/s, loss=7.015, bar=1.720, pos=0.996, token=2.838, dur=1.095, phrase=0.366]
# validation epoch: 12/1000: : 318it [00:02, 174.10it/s, loss=6.704, bar=1.779, pos=0.927, token=2.460, dur=1.175, phrase=0.362]
# validation epoch: 12/1000: : 320it [00:02, 174.10it/s, loss=6.620, bar=2.017, pos=0.851, token=2.369, dur=1.009, phrase=0.375]
# validation epoch: 12/1000: : 322it [00:02, 174.10it/s, loss=6.324, bar=1.527, pos=0.973, token=2.289, dur=1.152, phrase=0.383]
# validation epoch: 12/1000: : 324it [00:02, 174.10it/s, loss=8.888, bar=2.156, pos=1.586, token=2.595, dur=2.071, phrase=0.481]
# validation epoch: 12/1000: : 326it [00:02, 174.10it/s, loss=6.832, bar=1.131, pos=1.316, token=2.708, dur=1.251, phrase=0.426]
# validation epoch: 12/1000: : 328it [00:02, 174.10it/s, loss=6.838, bar=1.808, pos=1.211, token=2.356, dur=1.050, phrase=0.412]
# validation epoch: 12/1000: : 330it [00:02, 174.10it/s, loss=7.303, bar=1.760, pos=1.062, token=2.582, dur=1.392, phrase=0.507]
# validation epoch: 12/1000: : 332it [00:02, 176.43it/s, loss=7.303, bar=1.760, pos=1.062, token=2.582, dur=1.392, phrase=0.507]
# validation epoch: 12/1000: : 332it [00:02, 176.43it/s, loss=7.601, bar=1.763, pos=1.537, token=2.362, dur=1.546, phrase=0.393]
# validation epoch: 12/1000: : 334it [00:02, 176.43it/s, loss=8.154, bar=1.583, pos=1.799, token=2.122, dur=2.147, phrase=0.503]
# validation epoch: 12/1000: : 336it [00:02, 176.43it/s, loss=7.047, bar=1.379, pos=1.203, token=2.392, dur=1.565, phrase=0.509]
# validation epoch: 12/1000: : 338it [00:02, 176.43it/s, loss=8.862, bar=2.025, pos=1.795, token=2.372, dur=2.349, phrase=0.321]
# validation epoch: 12/1000: : 340it [00:02, 176.43it/s, loss=5.930, bar=1.173, pos=1.137, token=2.514, dur=0.787, phrase=0.319]
# validation epoch: 12/1000: : 342it [00:02, 176.43it/s, loss=6.592, bar=1.549, pos=1.113, token=2.381, dur=1.246, phrase=0.303]
# validation epoch: 12/1000: : 344it [00:02, 176.43it/s, loss=7.803, bar=1.460, pos=1.976, token=2.928, dur=1.165, phrase=0.275]
# validation epoch: 12/1000: : 346it [00:02, 176.43it/s, loss=8.131, bar=2.373, pos=1.747, token=2.128, dur=1.473, phrase=0.410]
# validation epoch: 12/1000: : 348it [00:02, 176.43it/s, loss=6.785, bar=1.617, pos=0.855, token=2.627, dur=1.222, phrase=0.465]
# validation epoch: 12/1000: : 350it [00:02, 176.43it/s, loss=8.244, bar=2.907, pos=1.454, token=1.947, dur=1.563, phrase=0.373]
# validation epoch: 12/1000: : 352it [00:02, 178.02it/s, loss=8.244, bar=2.907, pos=1.454, token=1.947, dur=1.563, phrase=0.373]
# validation epoch: 12/1000: : 352it [00:02, 178.02it/s, loss=8.459, bar=3.090, pos=1.512, token=2.280, dur=1.290, phrase=0.287]
# validation epoch: 12/1000: : 354it [00:02, 178.02it/s, loss=8.424, bar=2.420, pos=1.533, token=2.709, dur=1.334, phrase=0.428]
# validation epoch: 12/1000: : 356it [00:02, 178.02it/s, loss=8.009, bar=3.013, pos=1.100, token=2.542, dur=0.980, phrase=0.374]
# validation epoch: 12/1000: : 358it [00:02, 178.02it/s, loss=7.425, bar=1.914, pos=1.136, token=2.405, dur=1.483, phrase=0.487]
# validation epoch: 12/1000: : 360it [00:02, 178.02it/s, loss=6.044, bar=1.466, pos=0.907, token=2.216, dur=1.107, phrase=0.349]
# validation epoch: 12/1000: : 362it [00:02, 178.02it/s, loss=11.170, bar=5.148, pos=1.419, token=2.275, dur=1.791, phrase=0.537]
# validation epoch: 12/1000: : 364it [00:02, 178.02it/s, loss=7.938, bar=2.416, pos=2.066, token=2.249, dur=0.922, phrase=0.285]
# validation epoch: 12/1000: : 366it [00:02, 178.02it/s, loss=7.912, bar=1.867, pos=1.668, token=2.746, dur=1.361, phrase=0.271]
# validation epoch: 12/1000: : 368it [00:02, 178.02it/s, loss=7.123, bar=1.766, pos=1.207, token=1.946, dur=1.807, phrase=0.397]
# validation epoch: 12/1000: : 370it [00:02, 178.02it/s, loss=8.248, bar=1.546, pos=1.714, token=3.412, dur=1.300, phrase=0.276]
# validation epoch: 12/1000: : 372it [00:02, 179.35it/s, loss=8.248, bar=1.546, pos=1.714, token=3.412, dur=1.300, phrase=0.276]
# validation epoch: 12/1000: : 372it [00:02, 179.35it/s, loss=5.912, bar=1.643, pos=0.892, token=2.416, dur=0.642, phrase=0.319]
# validation epoch: 12/1000: : 374it [00:02, 179.35it/s, loss=9.728, bar=1.739, pos=1.901, token=4.375, dur=1.367, phrase=0.347]
# validation epoch: 12/1000: : 376it [00:02, 179.35it/s, loss=5.547, bar=1.208, pos=1.045, token=2.226, dur=0.780, phrase=0.287]
# validation epoch: 12/1000: : 378it [00:02, 179.35it/s, loss=8.115, bar=2.210, pos=1.733, token=2.433, dur=1.302, phrase=0.437]
# validation epoch: 12/1000: : 380it [00:02, 179.35it/s, loss=7.379, bar=1.898, pos=1.415, token=2.337, dur=1.331, phrase=0.398]
# validation epoch: 12/1000: : 382it [00:02, 179.35it/s, loss=7.953, bar=1.822, pos=1.413, token=2.513, dur=1.742, phrase=0.463]
# validation epoch: 12/1000: : 386it [00:02, 146.05it/s, loss=7.085, bar=1.618, pos=1.479, token=2.132, dur=1.392, phrase=0.465]
# training epoch: 13/1000:   0%|                                                                                               | 0/1545 [00:00<?, ?it/s]
# Validation loss decreased (7.776169 --> 7.776169).  Saving model ...
# Training Runinng Loss = 8.111280704547672, Validation Running Loss = 7.776168944304471
# training epoch: 13/1000:  52%|██████▋      | 796/1545 [00:11<00:11, 66.81it/s, loss=7.729, bar=1.759, pos=1.422, token=2.515, dur=1.592, phrase=0.442]
#   2%|▉                                      | 24/1000 [09:42<6:35:03, 24.29s/it]
#
# KeyboardInterrupt
